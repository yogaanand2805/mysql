# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:admin%40123@localhost:3306/test_db

# %%
# %%sql
# use test_db;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/test_db
# 0 rows affected.
# []

# %%
# %%sql
# show tables;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/test_db
# 3 rows affected.
# [('employee_salary',), ('high_salary',), ('staff',)]

# %%
# %%sql
# select * from employee_salary, high_salary;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/test_db
# 48 rows affected.
# [(1, 'Arun', 'Kumar', 'arun.kumar@example.com', datetime.date(2020, 3, 15), 55000.0, 8, 'Anjali', 'Verma', 'anjali.verma@example.com', datetime.date(2017, 6, 12), 82000.0),
#  (1, 'Arun', 'Kumar', 'arun.kumar@example.com', datetime.date(2020, 3, 15), 55000.0, 7, 'Karthik', 'Nair', 'karthik.nair@example.com', datetime.date(2020, 9, 30), 68000.0),
#  (1, 'Arun', 'Kumar', 'arun.kumar@example.com', datetime.date(2020, 3, 15), 55000.0, 5, 'Vikram', 'Reddy', 'vikram.reddy@example.com', datetime.date(2022, 5, 5), 51000.0),
#  (1, 'Arun', 'Kumar', 'arun.kumar@example.com', datetime.date(2020, 3, 15), 55000.0, 4, 'Sneha', 'Patel', 'sneha.patel@example.com', datetime.date(2018, 11, 20), 75000.0),
#  (1, 'Arun', 'Kumar', 'arun.kumar@example.com', datetime.date(2020, 3, 15), 55000.0, 2, 'Priya', 'Sharma', 'priya.sharma@example.com', datetime.date(2019, 7, 1), 62000.0),
#  (1, 'Arun', 'Kumar', 'arun.kumar@example.com', datetime.date(2020, 3, 15), 55000.0, 1, 'Arun', 'Kumar', 'arun.kumar@example.com', datetime.date(2020, 3, 15), 55000.0),
#  (2, 'Priya', 'Sharma', 'priya.sharma@example.com', datetime.date(2019, 7, 1), 62000.0, 8, 'Anjali', 'Verma', 'anjali.verma@example.com', datetime.date(2017, 6, 12), 82000.0),
#  (2, 'Priya', 'Sharma', 'priya.sharma@example.com', datetime.date(2019, 7, 1), 62000.0, 7, 'Karthik', 'Nair', 'karthik.nair@example.com', datetime.date(2020, 9, 30), 68000.0),
#  (2, 'Priya', 'Sharma', 'priya.sharma@example.com', datetime.date(2019, 7, 1), 62000.0, 5, 'Vikram', 'Reddy', 'vikram.reddy@example.com', datetime.date(2022, 5, 5), 51000.0),
#  (2, 'Priya', 'Sharma', 'priya.sharma@example.com', datetime.date(2019, 7, 1), 62000.0, 4, 'Sneha', 'Patel', 'sneha.patel@example.com', datetime.date(2018, 11, 20), 75000.0),
#  (2, 'Priya', 'Sharma', 'priya.sharma@example.com', datetime.date(2019, 7, 1), 62000.0, 2, 'Priya', 'Sharma', 'priya.sharma@example.com', datetime.date(2019, 7, 1), 62000.0),
#  (2, 'Priya', 'Sharma', 'priya.sharma@example.com', datetime.date(2019, 7, 1), 62000.0, 1, 'Arun', 'Kumar', 'arun.kumar@example.com', datetime.date(2020, 3, 15), 55000.0),
#  (3, 'Ravi', 'Menon', 'ravi.menon@example.com', datetime.date(2021, 1, 10), 48000.0, 8, 'Anjali', 'Verma', 'anjali.verma@example.com', datetime.date(2017, 6, 12), 82000.0),
#  (3, 'Ravi', 'Menon', 'ravi.menon@example.com', datetime.date(2021, 1, 10), 48000.0, 7, 'Karthik', 'Nair', 'karthik.nair@example.com', datetime.date(2020, 9, 30), 68000.0),
#  (3, 'Ravi', 'Menon', 'ravi.menon@example.com', datetime.date(2021, 1, 10), 48000.0, 5, 'Vikram', 'Reddy', 'vikram.reddy@example.com', datetime.date(2022, 5, 5), 51000.0),
#  (3, 'Ravi', 'Menon', 'ravi.menon@example.com', datetime.date(2021, 1, 10), 48000.0, 4, 'Sneha', 'Patel', 'sneha.patel@example.com', datetime.date(2018, 11, 20), 75000.0),
#  (3, 'Ravi', 'Menon', 'ravi.menon@example.com', datetime.date(2021, 1, 10), 48000.0, 2, 'Priya', 'Sharma', 'priya.sharma@example.com', datetime.date(2019, 7, 1), 62000.0),
#  (3, 'Ravi', 'Menon', 'ravi.menon@example.com', datetime.date(2021, 1, 10), 48000.0, 1, 'Arun', 'Kumar', 'arun.kumar@example.com', datetime.date(2020, 3, 15), 55000.0),
#  (4, 'Sneha', 'Patel', 'sneha.patel@example.com', datetime.date(2018, 11, 20), 75000.0, 8, 'Anjali', 'Verma', 'anjali.verma@example.com', datetime.date(2017, 6, 12), 82000.0),
#  (4, 'Sneha', 'Patel', 'sneha.patel@example.com', datetime.date(2018, 11, 20), 75000.0, 7, 'Karthik', 'Nair', 'karthik.nair@example.com', datetime.date(2020, 9, 30), 68000.0),
#  (4, 'Sneha', 'Patel', 'sneha.patel@example.com', datetime.date(2018, 11, 20), 75000.0, 5, 'Vikram', 'Reddy', 'vikram.reddy@example.com', datetime.date(2022, 5, 5), 51000.0),
#  (4, 'Sneha', 'Patel', 'sneha.patel@example.com', datetime.date(2018, 11, 20), 75000.0, 4, 'Sneha', 'Patel', 'sneha.patel@example.com', datetime.date(2018, 11, 20), 75000.0),
#  (4, 'Sneha', 'Patel', 'sneha.patel@example.com', datetime.date(2018, 11, 20), 75000.0, 2, 'Priya', 'Sharma', 'priya.sharma@example.com', datetime.date(2019, 7, 1), 62000.0),
#  (4, 'Sneha', 'Patel', 'sneha.patel@example.com', datetime.date(2018, 11, 20), 75000.0, 1, 'Arun', 'Kumar', 'arun.kumar@example.com', datetime.date(2020, 3, 15), 55000.0),
#  (5, 'Vikram', 'Reddy', 'vikram.reddy@example.com', datetime.date(2022, 5, 5), 51000.0, 8, 'Anjali', 'Verma', 'anjali.verma@example.com', datetime.date(2017, 6, 12), 82000.0),
#  (5, 'Vikram', 'Reddy', 'vikram.reddy@example.com', datetime.date(2022, 5, 5), 51000.0, 7, 'Karthik', 'Nair', 'karthik.nair@example.com', datetime.date(2020, 9, 30), 68000.0),
#  (5, 'Vikram', 'Reddy', 'vikram.reddy@example.com', datetime.date(2022, 5, 5), 51000.0, 5, 'Vikram', 'Reddy', 'vikram.reddy@example.com', datetime.date(2022, 5, 5), 51000.0),
#  (5, 'Vikram', 'Reddy', 'vikram.reddy@example.com', datetime.date(2022, 5, 5), 51000.0, 4, 'Sneha', 'Patel', 'sneha.patel@example.com', datetime.date(2018, 11, 20), 75000.0),
#  (5, 'Vikram', 'Reddy', 'vikram.reddy@example.com', datetime.date(2022, 5, 5), 51000.0, 2, 'Priya', 'Sharma', 'priya.sharma@example.com', datetime.date(2019, 7, 1), 62000.0),
#  (5, 'Vikram', 'Reddy', 'vikram.reddy@example.com', datetime.date(2022, 5, 5), 51000.0, 1, 'Arun', 'Kumar', 'arun.kumar@example.com', datetime.date(2020, 3, 15), 55000.0),
#  (6, 'Meena', 'Iyer', 'meena.iyer@example.com', datetime.date(2023, 2, 14), 46000.0, 8, 'Anjali', 'Verma', 'anjali.verma@example.com', datetime.date(2017, 6, 12), 82000.0),
#  (6, 'Meena', 'Iyer', 'meena.iyer@example.com', datetime.date(2023, 2, 14), 46000.0, 7, 'Karthik', 'Nair', 'karthik.nair@example.com', datetime.date(2020, 9, 30), 68000.0),
#  (6, 'Meena', 'Iyer', 'meena.iyer@example.com', datetime.date(2023, 2, 14), 46000.0, 5, 'Vikram', 'Reddy', 'vikram.reddy@example.com', datetime.date(2022, 5, 5), 51000.0),
#  (6, 'Meena', 'Iyer', 'meena.iyer@example.com', datetime.date(2023, 2, 14), 46000.0, 4, 'Sneha', 'Patel', 'sneha.patel@example.com', datetime.date(2018, 11, 20), 75000.0),
#  (6, 'Meena', 'Iyer', 'meena.iyer@example.com', datetime.date(2023, 2, 14), 46000.0, 2, 'Priya', 'Sharma', 'priya.sharma@example.com', datetime.date(2019, 7, 1), 62000.0),
#  (6, 'Meena', 'Iyer', 'meena.iyer@example.com', datetime.date(2023, 2, 14), 46000.0, 1, 'Arun', 'Kumar', 'arun.kumar@example.com', datetime.date(2020, 3, 15), 55000.0),
#  (7, 'Karthik', 'Nair', 'karthik.nair@example.com', datetime.date(2020, 9, 30), 68000.0, 8, 'Anjali', 'Verma', 'anjali.verma@example.com', datetime.date(2017, 6, 12), 82000.0),
#  (7, 'Karthik', 'Nair', 'karthik.nair@example.com', datetime.date(2020, 9, 30), 68000.0, 7, 'Karthik', 'Nair', 'karthik.nair@example.com', datetime.date(2020, 9, 30), 68000.0),
#  (7, 'Karthik', 'Nair', 'karthik.nair@example.com', datetime.date(2020, 9, 30), 68000.0, 5, 'Vikram', 'Reddy', 'vikram.reddy@example.com', datetime.date(2022, 5, 5), 51000.0),
#  (7, 'Karthik', 'Nair', 'karthik.nair@example.com', datetime.date(2020, 9, 30), 68000.0, 4, 'Sneha', 'Patel', 'sneha.patel@example.com', datetime.date(2018, 11, 20), 75000.0),
#  (7, 'Karthik', 'Nair', 'karthik.nair@example.com', datetime.date(2020, 9, 30), 68000.0, 2, 'Priya', 'Sharma', 'priya.sharma@example.com', datetime.date(2019, 7, 1), 62000.0),
#  (7, 'Karthik', 'Nair', 'karthik.nair@example.com', datetime.date(2020, 9, 30), 68000.0, 1, 'Arun', 'Kumar', 'arun.kumar@example.com', datetime.date(2020, 3, 15), 55000.0),
#  (8, 'Anjali', 'Verma', 'anjali.verma@example.com', datetime.date(2017, 6, 12), 82000.0, 8, 'Anjali', 'Verma', 'anjali.verma@example.com', datetime.date(2017, 6, 12), 82000.0),
#  (8, 'Anjali', 'Verma', 'anjali.verma@example.com', datetime.date(2017, 6, 12), 82000.0, 7, 'Karthik', 'Nair', 'karthik.nair@example.com', datetime.date(2020, 9, 30), 68000.0),
#  (8, 'Anjali', 'Verma', 'anjali.verma@example.com', datetime.date(2017, 6, 12), 82000.0, 5, 'Vikram', 'Reddy', 'vikram.reddy@example.com', datetime.date(2022, 5, 5), 51000.0),
#  (8, 'Anjali', 'Verma', 'anjali.verma@example.com', datetime.date(2017, 6, 12), 82000.0, 4, 'Sneha', 'Patel', 'sneha.patel@example.com', datetime.date(2018, 11, 20), 75000.0),
#  (8, 'Anjali', 'Verma', 'anjali.verma@example.com', datetime.date(2017, 6, 12), 82000.0, 2, 'Priya', 'Sharma', 'priya.sharma@example.com', datetime.date(2019, 7, 1), 62000.0),
#  (8, 'Anjali', 'Verma', 'anjali.verma@example.com', datetime.date(2017, 6, 12), 82000.0, 1, 'Arun', 'Kumar', 'arun.kumar@example.com', datetime.date(2020, 3, 15), 55000.0)]
