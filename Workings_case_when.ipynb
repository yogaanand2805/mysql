# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:admin%40123@localhost:3306/test_db

# %%
# %%sql
# CREATE TABLE new_employees (
#     emp_id INT AUTO_INCREMENT,
#     emp_code VARCHAR(20) NOT NULL,
#     name VARCHAR(100) NOT NULL,
#     email VARCHAR(100),
#     salary DECIMAL(10,2) CHECK (salary > 0),
#     department_id INT,
#     hire_date DATE,
#
#      CONSTRAINT pk_employees PRIMARY KEY (emp_id),
#     CONSTRAINT uq_emp_code UNIQUE (emp_code),
#     CONSTRAINT uq_email UNIQUE (email)
#     );
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/test_db
# 0 rows affected.
# []

# %%
# %%sql
# INSERT INTO new_employees
# (emp_code, name, email, salary, department_id, hire_date)
# VALUES
# ('EMP001', 'Alice Johnson', 'alice@company.com', 55000, 10, '2022-06-01'),
# ('EMP002', 'Bob Smith', 'bob@company.com', 62000, 20, '2021-03-15'),
# ('EMP003', 'Charlie Brown', 'charlie@company.com', 48000, 10, '2023-01-10'),
# ('EMP004', 'David Miller', 'david@company.com', 70000, 30, '2020-11-20'),
# ('EMP005', 'Eva Wilson', 'eva@company.com', 52000, 20, '2022-08-05'),
# ('EMP006', 'Frank Thomas', 'frank@company.com', 58000, 10, '2021-01-25'),
# ('EMP007', 'Grace Lee', 'grace@company.com', 65000, 40, '2019-09-14'),
# ('EMP008', 'Henry Clark', 'henry@company.com', 47000, 30, '2023-02-01'),
# ('EMP009', 'Irene Lewis', 'irene@company.com', 54000, 20, '2022-04-18'),
# ('EMP010', 'Jack Walker', 'jack@company.com', 60000, 10, '2021-12-10'),
# ('EMP011', 'Karen Hall', 'karen@company.com', 72000, 40, '2020-06-30'),
# ('EMP012', 'Leo Young', 'leo@company.com', 51000, 30, '2022-10-09'),
# ('EMP013', 'Mona King', 'mona@company.com', 49000, 20, '2023-03-22'),
# ('EMP014', 'Nathan Scott', 'nathan@company.com', 68000, 10, '2019-05-16'),
# ('EMP015', 'Olivia Adams', 'olivia@company.com', 75000, 40, '2018-07-01'),
# ('EMP016', 'Peter Baker', 'peter@company.com', 56000, 30, '2021-09-27'),
# ('EMP017', 'Quincy Turner', 'quincy@company.com', 53000, 20, '2022-01-11'),
# ('EMP018', 'Rachel Perez', 'rachel@company.com', 61000, 10, '2020-02-19'),
# ('EMP019', 'Sam Roberts', 'sam@company.com', 59000, 30, '2021-06-08'),
# ('EMP020', 'Tina Collins', 'tina@company.com', 67000, 40, '2019-11-03');
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/test_db
# 20 rows affected.
# []

# %%
# %%sql
# SELECT
#     emp_id,
#     name,
#     salary,
#     CASE
#         WHEN salary >= 55000 THEN 'High'
#         WHEN salary >= 40000 THEN 'Medium'
#         ELSE 'Low'
#     END AS salary_level
# FROM new_employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/test_db
# 20 rows affected.
# [(1, 'Alice Johnson', Decimal('55000.00'), 'High'),
#  (2, 'Bob Smith', Decimal('62000.00'), 'High'),
#  (3, 'Charlie Brown', Decimal('48000.00'), 'Medium'),
#  (4, 'David Miller', Decimal('70000.00'), 'High'),
#  (5, 'Eva Wilson', Decimal('52000.00'), 'Medium'),
#  (6, 'Frank Thomas', Decimal('58000.00'), 'High'),
#  (7, 'Grace Lee', Decimal('65000.00'), 'High'),
#  (8, 'Henry Clark', Decimal('47000.00'), 'Medium'),
#  (9, 'Irene Lewis', Decimal('54000.00'), 'Medium'),
#  (10, 'Jack Walker', Decimal('60000.00'), 'High'),
#  (11, 'Karen Hall', Decimal('72000.00'), 'High'),
#  (12, 'Leo Young', Decimal('51000.00'), 'Medium'),
#  (13, 'Mona King', Decimal('49000.00'), 'Medium'),
#  (14, 'Nathan Scott', Decimal('68000.00'), 'High'),
#  (15, 'Olivia Adams', Decimal('75000.00'), 'High'),
#  (16, 'Peter Baker', Decimal('56000.00'), 'High'),
#  (17, 'Quincy Turner', Decimal('53000.00'), 'Medium'),
# ...
