# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:admin%40123@localhost:3306/test_db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
# use test_db;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/test_db
# 0 rows affected.
# []

# %%
# %%sql
# create table if not exists employee_salary(
# id int primary key auto_increment,
# first_name varchar(100) not null,
# last_name varchar(100) not null,
# email_id varchar(100) unique not null,
# date_of_joining date not null,
# salary double not null
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/test_db
# 0 rows affected.
# []

# %%
# %%sql
# INSERT INTO employee_salary
# (first_name, last_name, email_id, date_of_joining, salary)
# VALUES
# ('Arun', 'Kumar', 'arun.kumar@example.com', '2020-03-15', 55000.00),
# ('Priya', 'Sharma', 'priya.sharma@example.com', '2019-07-01', 62000.00),
# ('Ravi', 'Menon', 'ravi.menon@example.com', '2021-01-10', 48000.00),
# ('Sneha', 'Patel', 'sneha.patel@example.com', '2018-11-20', 75000.00),
# ('Vikram', 'Reddy', 'vikram.reddy@example.com', '2022-05-05', 51000.00),
# ('Meena', 'Iyer', 'meena.iyer@example.com', '2023-02-14', 46000.00),
# ('Karthik', 'Nair', 'karthik.nair@example.com', '2020-09-30', 68000.00),
# ('Anjali', 'Verma', 'anjali.verma@example.com', '2017-06-12', 82000.00);
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/test_db
# 8 rows affected.
# []

# %%
# %%sql
# create table high_salary as
# select * from employee_salary
# where salary > 50000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/test_db
# 6 rows affected.
# []

# %%
# %%sql
# select * from high_salary;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/test_db
# 6 rows affected.
# [(1, 'Arun', 'Kumar', 'arun.kumar@example.com', datetime.date(2020, 3, 15), 55000.0),
#  (2, 'Priya', 'Sharma', 'priya.sharma@example.com', datetime.date(2019, 7, 1), 62000.0),
#  (4, 'Sneha', 'Patel', 'sneha.patel@example.com', datetime.date(2018, 11, 20), 75000.0),
#  (5, 'Vikram', 'Reddy', 'vikram.reddy@example.com', datetime.date(2022, 5, 5), 51000.0),
#  (7, 'Karthik', 'Nair', 'karthik.nair@example.com', datetime.date(2020, 9, 30), 68000.0),
#  (8, 'Anjali', 'Verma', 'anjali.verma@example.com', datetime.date(2017, 6, 12), 82000.0)]

# %%
# %%sql
# create temporary table work_note as
# select * from employee_salary
# where salary > 50000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/test_db
# 6 rows affected.
# []
