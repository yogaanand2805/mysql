# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:admin%40123@localhost:3306/test_db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
# use test_db;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/test_db
# 0 rows affected.
# []

# %%
# %%sql
# drop table if exists empolyees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/test_db
# 0 rows affected.
# []

# %%
# %%sql
# create table employees (
#     id int primary key auto_increment,
#     name varchar(100),
#     department varchar(100),
#     salary float
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/test_db
# (mysql.connector.errors.ProgrammingError) 1050 (42S01): Table 'employees' already exists
# [SQL: create table employees (
#     id int primary key auto_increment,
#     name varchar(100),
#     department varchar(100),
#     salary float
# );]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# show tables;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/test_db
# 3 rows affected.
# [('employee_salary',), ('employees',), ('high_salary',)]

# %%
# %%sql
# alter table employees
# add column date_of_joining date;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/test_db
# 0 rows affected.
# []

# %%
# %%sql
# describe empolyees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/test_db
# (mysql.connector.errors.ProgrammingError) 1146 (42S02): Table 'test_db.empolyees' doesn't exist
# [SQL: describe empolyees;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# alter table employees
# drop column ate_of_joining date;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/test_db
# (mysql.connector.errors.ProgrammingError) 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'date' at line 2
# [SQL: alter table employees
# drop column ate_of_joining date;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# alter table employees rename to staff;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/test_db
# 0 rows affected.
# []

# %%
# %%sql
# alter table staff
# rename column name to first_name;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/test_db
# 0 rows affected.
# []

# %%
# %%sql
# describe staff;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/test_db
# 5 rows affected.
# [('id', 'int', 'NO', 'PRI', None, 'auto_increment'),
#  ('first_name', 'varchar(100)', 'YES', '', None, ''),
#  ('department', 'varchar(100)', 'YES', '', None, ''),
#  ('salary', 'float', 'YES', '', None, ''),
#  ('date_of_joining', 'date', 'YES', '', None, '')]
